# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Function to read csv files
# pd.read_csv()
df_premier25 = pd.read_csv('https://football-data.co.uk/mmz4281/2526/E0.csv')

# %%
# Show dataframe
df_premier25
# Out:
#     Div        Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  15/08/2025  20:00    Liverpool     Bournemouth     4     2   H     1
# 1    E0  16/08/2025  12:30  Aston Villa       Newcastle     0     0   D     0
# 2    E0  16/08/2025  15:00     Brighton          Fulham     1     1   D     0
# 3    E0  16/08/2025  15:00   Sunderland        West Ham     3     0   H     0
# 4    E0  16/08/2025  15:00    Tottenham         Burnley     3     0   H     1
# ..   ..         ...    ...          ...             ...   ...   ...  ..   ...
# 114  E0  22/11/2025  15:00    Liverpool   Nott'm Forest     0     3   A     0
# 115  E0  22/11/2025  15:00       Wolves  Crystal Palace     0     2   A     0
# 116  E0  22/11/2025  17:30    Newcastle        Man City     2     1   H     0
# 117  E0  23/11/2025  14:00        Leeds     Aston Villa     1     2   A     1
# 118  E0  23/11/2025  16:30      Arsenal       Tottenham     4     1   H     2
#
# ...

# %%
# Rename dataframe
df_premier25.rename(columns={'FTHG':'home_goals', 'FTAG':'away_goals'}, inplace=True)

# %%
# Show changed dataframe
df_premier25
# Out:
#     Div        Date   Time     HomeTeam        AwayTeam  home_goals  \
# 0    E0  15/08/2025  20:00    Liverpool     Bournemouth           4
# 1    E0  16/08/2025  12:30  Aston Villa       Newcastle           0
# 2    E0  16/08/2025  15:00     Brighton          Fulham           1
# 3    E0  16/08/2025  15:00   Sunderland        West Ham           3
# 4    E0  16/08/2025  15:00    Tottenham         Burnley           3
# ..   ..         ...    ...          ...             ...         ...
# 114  E0  22/11/2025  15:00    Liverpool   Nott'm Forest           0
# 115  E0  22/11/2025  15:00       Wolves  Crystal Palace           0
# 116  E0  22/11/2025  17:30    Newcastle        Man City           2
# 117  E0  23/11/2025  14:00        Leeds     Aston Villa           1
# 118  E0  23/11/2025  16:30      Arsenal       Tottenham           4
#
#      away_goals FTR  HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# ...
