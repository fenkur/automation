# %%
# !pip install tk ghostscript

# %%
# !pip install camelot-py

# %%
import camelot

# %%
tables = camelot.read_pdf('foo.pdf', pages=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tables = camelot.read_pdf('foo.pdf', pages=1)
#
# File ~\anaconda3\Lib\site-packages\camelot\io.py:132, in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     129     warnings.simplefilter("ignore")
#     131 validate_input(kwargs, flavor=flavor)
# --> 132 p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133 kwargs = remove_extra(kwargs, flavor=flavor)
#     134 tables = p.parse(
#     135     flavor=flavor,
#     136     suppress_stdout=suppress_stdout,
#    (...)
#     139     **kwargs,
#     140 )
#
# File ~\anaconda3\Lib\site-packages\camelot\handlers.py:78, in PDFHandler.__init__(self, filepath, pages, password, debug)
#      76 else:
#      77     self.password = password
# ...
